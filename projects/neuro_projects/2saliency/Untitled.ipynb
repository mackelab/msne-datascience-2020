# %% [markdown]
# ## Saliency Project
# by Jesse Torija

# %% [markdown]
# ### Libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %% [markdown]
# ### Functions

# %%
def four_by_four(img,titles):
    plt.figure(figsize = (12,7))
    plt.subplot(2,2,1) , plt.imshow(img) , plt.title('Original Image')
    j = 0
    while j < 3 :
        plt.subplot(2,2,j+2)
        plt.imshow(img[:,:,j], cmap = 'gray')
        plt.title(h[j] + ' channel')
        j = j + 1
    return

# %%
img = plt.imread('/Users/torijamaximoj2/Desktop/salience_08.png')
plt.imshow(img)

# %%
color = ["red", "green", "blue"]
four_by_four(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-326d5984e676> in <module>
# ----> 1 four_by_four(img)
#
# <ipython-input-7-acc6e5eb6121> in four_by_four(img)
#       6         plt.subplot(2,2,j+2)
#       7         plt.imshow(img[:,:,j], cmap = 'gray')
# ----> 8         plt.title(color[j] + ' channel')
#       9         j = j + 1
#      10     return
#
# NameError: name 'color' is not defined
